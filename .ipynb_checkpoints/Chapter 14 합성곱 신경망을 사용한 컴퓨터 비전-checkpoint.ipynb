# %% [markdown]
# [참고](https://github.com/rickiepark/handson-ml2/blob/master/14_deep_computer_vision_with_cnns.ipynb)

# %% [markdown]
# - **합성곱 신경망**(convolutional neural network, CNN) : 대뇌의 시각 피질(cortex) 연구에서 시작되었고 이미지 인식 분야에 사용되었다. <br/>
#     이미지 검색 서비스, 자율주행 자동차, 영상 자동 분류 시스템 등에 큰 기여를 하였으며 <br/>
#     **음성 인식**(voice recognition)이나 **자연어 처리**(natural language processing, NLP) 같은 다른 작업에도 많이 사용됨.
#
# # 14.1 시각 피질 구조
# 시각 피질 안의 많은 뉴런이 작은 **국부 수용장**(local receptive field)을 가진다. 즉 뉴런들이 사야의 일부 범위 안에 있는 시각 자극에만 반응한다.
#
# # 14.2 합성곱 층
# - 합성곱 층(convolutional layer)
#     - 첫 번째 합성곱 층 : 층의 수용장 안에 있는 픽셀에만 연결. 작은 저수준 특성에 집중하도록 함.
#     - 두 번째 합성곱 층 : 첫 번째 층의 작은 사각형 안에 위치한 뉴런에 연결. 더 큰 고수준 특성으로 조합해나가도록 함.
# - 제로 패딩(zero padding) : 높이와 너비를 이전 층과 같게 하기 위해 입력의 주위에 0을 추가하는 것.
# - 스트라이드(stride) : 한 수용장과 다음 수용장 사이 간격
#
# ## 14.2.1 필터
# 필터(filter, 또는 합성곱 커널 convolution kernel) : 가중치 세트. 하나의 필터는 하나의 **특성 맵**(feature map)을 만든다.
#
# ## 14.2.2 여러 가지 특성 맵 쌓기
# - CNN : 한 지점에서 패턴을 인식하도록 학습되었다면 다른 어느 위치에 있는 패턴도 인식할 수 있음.
# - DNN : 한 지점에 있는 패턴을 인식하도록 학습되었다면 오직 패턴이 그 위치에 있을 때만 감지할 수 있음.
#
# - 컬러 채널 : RBG, 흑백, 가시광선이나 적외선 같이 종류에 따라 가지는 채널 수가 다르다.
#
# ## 14.2.3 텐서플로 구현

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import tensorflow as tf

import numpy as np
from sklearn.datasets import load_sample_image

# Load sample images
china = load_sample_image("china.jpg") / 255 # 각 컬러 채널의 픽셀 강도는 0에서 255 사이의 값을 가진 바이트 하나로 표현됨.
flower = load_sample_image("flower.jpg") / 255
images = np.array([china, flower])
batch_size, height, width, channels = images.shape

# Create 2 filters
filters = np.zeros(shape=(7, 7, channels, 2), dtype=np.float32) # 7X7 필터
filters[:, 3, :, 0] = 1  # vertical line
filters[3, :, :, 1] = 1  # horizontal line

outputs = tf.nn.conv2d(images, filters, strides=1, padding="SAME") # padding을 VALID로 지정하면 제로 패딩을 사용하지 않는다.

plt.imshow(outputs[0, :, :, 1], cmap="gray") # plot 1st image's 2nd feature map
plt.axis("off") # Not shown in the book
plt.show()

# %%
from tensorflow import keras

conv = keras.layers.Conv2D(filters=32, kernel_size=3, strides=1,
                           padding="SAME", activation="relu")

# %% [markdown]
# ## 14.2.4 메모리 요구 사항
# 추론(inference)을 할 때, 즉 새로운 샘플에 대한 예측을 만들 때는 하나의 층이 점유하고 있는 RAM은 다음 층의 계산이 완료되자마자 해제될 수 있음. <br/>
# 그러므로 연속된 두 개의 층에서 필요로 하는 만큼의 RAM만 가지고 있으면 됨. <br/>
# 메모리 부족으로 훈련이 실패한담녀 미니배치 크기를 줄여보자!
#
# # 14.3 풀링 층
# - 풀링 층(pooling layer) : 계산량과 메모리 사용량, 파라미터 수를 줄이기 위해 입력 이미지의 **부표본**(subsample, 축소본)을 만드는 목적의 층
# - 최대 풀링 층(max pooling layer) <br/>
#     : 가장 큰 입력값이 다음층으로 전달되고 다른 값은 버려지는 층. 작은 변화에도 일정 수준의 **불변성**(invariansce)을 만들어줌.
# - 풀링 커널(pooling kernel, 풀링 함수) : 가중치가 없으며 상태가 없는 슬라이딩 윈도우.
#
# ## 14.3.1 텐서플로 구현

# %%
max_pool = keras.layers.MaxPool2D(pool_size=2)

# %% [markdown]
# - 평균 풀링 층(average pooling layer) : 최댓값이 아닌 평균을 계산해 전달되는 층.

# %%
def crop(images):
    return images[150:220, 130:250]

# %%
cropped_images = np.array([crop(image) for image in images], dtype=np.float32)
output = max_pool(cropped_images)

# %%
avg_pool = keras.layers.AvgPool2D(pool_size=2)
output_avg = avg_pool(cropped_images)

# %%
depth_pool = keras.layers.Lambda(lambda X: tf.nn.max_pool(
    X, ksize=(1, 1, 1, 3), strides=(1, 1, 1, 3), padding="VALID"))
with tf.device("/cpu:0"): # there is no GPU-kernel yet
    depth_output = depth_pool(cropped_images)
depth_output.shape
# Out:
# TensorShape([2, 70, 120, 1])

# %% [markdown]
# - 전역 평균 풀링 층(global average pooling layer) : 각 특성 맵의 평균을 계산하는 것. 각 샘플의 특성 맵마다 하나의 숫자를 출력.

# %%
global_avg_pool = keras.layers.GlobalAvgPool2D()

# %%
output_global_avg2 = keras.layers.Lambda(lambda X: tf.reduce_mean(X, axis=[1, 2]))

# %% [markdown]
# # 14.4 CNN 구조

# %%
# 패션 MNIST 데이터셋 문제를 해결하기 위한 간단한 CNN
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

X_mean = X_train.mean(axis=0, keepdims=True)
X_std = X_train.std(axis=0, keepdims=True) + 1e-7
X_train = (X_train - X_mean) / X_std
X_valid = (X_valid - X_mean) / X_std
X_test = (X_test - X_mean) / X_std

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
from functools import partial

DefaultConv2D = partial(keras.layers.Conv2D,
                        kernel_size=3, activation='relu', padding="SAME")

model = keras.models.Sequential([
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[28, 28, 1]), # 64개의 필터 사용
    keras.layers.MaxPooling2D(pool_size=2), # 풀링 크기가 2인 최대 풀링 층 추가
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    keras.layers.MaxPooling2D(pool_size=2),
    DefaultConv2D(filters=256),
    DefaultConv2D(filters=256),
    keras.layers.MaxPooling2D(pool_size=2),
    keras.layers.Flatten(),
    keras.layers.Dense(units=128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=64, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(units=10, activation='softmax'),
])

# %% [markdown]
# ## 14.4.1 LeNet-5
# 가장 널리 알려진 CNN 구조. 손글씨 숫자 인식(MNIST)에 널리 사용됨.
#
# ## 14.4.2 AlexNet
# 더 크고 깊은 LeNet-5. 처음으로 합성곱 층 위에 풀링 층을 쌓지 않고 바로 합성곱 층끼리 쌓았음. <br/>
# 과대 적합을 줄이기 위해
# 1. 훈련하는 동안 완전 연결 출력에 드롭아웃을 50% 비율로 적용.
# 2. 훈련 이미지를 랜덤하게 여러 간격으로 이동하거나 수평으로 뒤집고 조명을 바꾸는 식으로 **데이터 증식**(data augmentation)을 수행
#
# ### 데이터 증식
# 진짜 같은 훈련 샘플을 인공적으로 생성하여 훈련 세트의 크기를 늘려 과대적합을 줄인다.
#
# - LRN(local respnse normalization) : 가장 강하게 활성화된 뉴런이 다른 특성 맵에 있는 같은 위치의 뉴런을 억제하는 정규화 단계.
#
# ## 14.4.3 GoogLeNet
# **인셉션 모듈**(inception module)이라는 서브네트워크를 가지고 있어서 효과적으로 파라미터를 사용해 실제로 AlexNet보다 10배 적은 파라미터를 가짐. <br/>
# 이는 1X1 커널의 합성곱 층을 가지는데, 이는 입력보다 더 적은 특성 맵을 출력하므로 차원을 줄인다는 의미인 **병목 층**(bottleneck layer) 역할을 담당한다.
#
# ## 14.4.4 VGGNet
# 2개 또는 3개의 합성곱 층 뒤에 풀링 층이 나오고 다시 2개 또는 3개의 합성곱 층과 풀링 층이 등장하는 식.
#
# ## 14.4.5 ResNet(residual network, 잔차 네트워크)
# - 핵심 요소 : **스킵 연결**(skip connection), **숏컷 연결**(shortcut connection)
# - 잔차 학습(residual learning) : 목적 함수 $h( \text{x} )$ 대신 입력 $ \text{x} $를 이용해 $f( \text{x} ) = h( \text{x} ) - \text{x} $를 학습하는 것.
# - 잔차 유닛(residual unit, RU) : 스킵 연결을 가진 작은 신경망.
#
# ## 14.4.6 Xception
# GoogLeNet 구조의 또 다른 변종이지만 인셉션 모듈은 **깊이별 분리 합성곱 층**(depthwise separable convolution layer)이라는 특별한 층으로 대체.
#
# ## 14.4.7 SENet(squeeze-and-excitation network)
# 원래 구조에 있는 모든 유닛에 **SE 블록**이라는 작은 신경망을 추가하여 성능을 향상시킴.
# - SE-Inception : 인셉션 네트워크를 확장한 버전
# - SE-ResNet : ResNet을 확장한 버전
#
# # 14.5 케라스를 사용해 ResNet-34 CNN 구현하기

# %%
# ResNet-34
DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, strides=1,
                        padding="SAME", use_bias=False)

class ResidualUnit(keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.main_layers = [
            DefaultConv2D(filters, strides=strides),
            keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            keras.layers.BatchNormalization()]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConv2D(filters, kernel_size=1, strides=strides),
                keras.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
model = keras.models.Sequential()
model.add(DefaultConv2D(64, kernel_size=7, strides=2,
                        input_shape=[224, 224, 3]))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Activation("relu"))
model.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="SAME"))
prev_filters = 64
for filters in [64] * 3 + [128] * 4 + [256] * 6 + [512] * 3:
    strides = 1 if filters == prev_filters else 2
    model.add(ResidualUnit(filters, strides=strides))
    prev_filters = filters
model.add(keras.layers.GlobalAvgPool2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(10, activation="softmax"))

# %% [markdown]
# # 14.6 케라스에서 제공하는 사전훈련된 모델 사용하기

# %%
model = keras.applications.resnet50.ResNet50(weights="imagenet")
# Out:
# ...
# 102973440/102967424 [==============================] - 67s 1us/step

# %%
def plot_color_image(image):
    plt.imshow(image, interpolation="nearest")
    plt.axis("off")

images_resized = tf.image.resize(images, [224, 224])
plot_color_image(images_resized[0])
plt.show()

# %%
inputs = keras.applications.resnet50.preprocess_input(images_resized * 255)
Y_proba = model.predict(inputs)

# %%
top_K = keras.applications.resnet50.decode_predictions(Y_proba, top=3)
for image_index in range(len(images)):
    print("Image #{}".format(image_index))
    for class_id, name, y_proba in top_K[image_index]:
        print("  {} - {:12s} {:.2f}%".format(class_id, name, y_proba * 100))
    print()
# Out:
# ...
# 40960/35363 [==================================] - 0s 1us/step
# Image #0
#   n02825657 - bell_cote    82.35%
#   n03877845 - palace       6.75%
#   n03781244 - monastery    4.19%
#
# Image #1
#   n03530642 - honeycomb    49.83%
#   n13040303 - stinkhorn    33.95%
#   n02206856 - bee          4.35%

# %% [markdown]
# # 14.7 사전훈련된 모델을 사용한 전이 학습

# %%
import tensorflow_datasets as tfds

dataset, info = tfds.load("tf_flowers", as_supervised=True, with_info=True)
# Out:
# ...
# Dataset tf_flowers downloaded and prepared to C:\Users\sarah\tensorflow_datasets\tf_flowers\3.0.1. Subsequent calls will reuse this data.

# %%
dataset_size = info.splits["train"].num_examples
dataset_size
# Out:
# 3670

# %%
class_names = info.features["label"].names
class_names
# Out:
# ['dandelion', 'daisy', 'tulips', 'sunflowers', 'roses']

# %%
n_classes = info.features["label"].num_classes

# %%
test_set_raw, valid_set_raw, train_set_raw = tfds.load(
    "tf_flowers",
    split=["train[:10%]", "train[10%:25%]", "train[25%:]"],
    as_supervised=True)

# %%
def preprocess(image, label):
    resized_image = tf.image.resize(image, [224, 224])
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label

# %%
def central_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]])
    top_crop = (shape[0] - min_dim) // 4
    bottom_crop = shape[0] - top_crop
    left_crop = (shape[1] - min_dim) // 4
    right_crop = shape[1] - left_crop
    return image[top_crop:bottom_crop, left_crop:right_crop]

def random_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]]) * 90 // 100
    return tf.image.random_crop(image, [min_dim, min_dim, 3])

def preprocess(image, label, randomize=False):
    if randomize:
        cropped_image = random_crop(image)
        cropped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        cropped_image = central_crop(image)
    resized_image = tf.image.resize(cropped_image, [224, 224])
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label

batch_size = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(preprocess, randomize=True)).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

# %%
base_model = keras.applications.xception.Xception(weights="imagenet",
                                                  include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(n_classes, activation="softmax")(avg)
model = keras.models.Model(inputs=base_model.input, outputs=output)
# Out:
# ...
# 83689472/83683744 [==============================] - 27s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

optimizer = keras.optimizers.SGD(lr=0.2, momentum=0.9, decay=0.01)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(train_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_data=valid_set,
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    epochs=5)
# Out:
# Epoch 1/5
# 86/86 [==============================] - 303s 3s/step - loss: 1.5421 - accuracy: 0.6949 - val_loss: 1.1398 - val_accuracy: 0.8309
# Epoch 2/5
# 86/86 [==============================] - 308s 4s/step - loss: 0.5345 - accuracy: 0.8997 - val_loss: 0.7573 - val_accuracy: 0.8732
# Epoch 3/5
# 86/86 [==============================] - 305s 4s/step - loss: 0.2693 - accuracy: 0.9309 - val_loss: 0.6783 - val_accuracy: 0.8842
# Epoch 4/5
# 86/86 [==============================] - 314s 4s/step - loss: 0.2480 - accuracy: 0.9368 - val_loss: 0.6405 - val_accuracy: 0.8860
# Epoch 5/5
# 86/86 [==============================] - 317s 4s/step - loss: 0.1587 - accuracy: 0.9503 - val_loss: 0.6719 - val_accuracy: 0.8860

# %%
for layer in base_model.layers:
    layer.trainable = True

optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9,
                                 nesterov=True, decay=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(train_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_data=valid_set,
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    epochs=40)

# %% [markdown]
# # 14.8 분류와 위치 추정

# %%
base_model = keras.applications.xception.Xception(weights="imagenet",
                                                  include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
class_output = keras.layers.Dense(n_classes, activation="softmax")(avg)
loc_output = keras.layers.Dense(4)(avg)
model = keras.models.Model(inputs=base_model.input,
                           outputs=[class_output, loc_output])
model.compile(loss=["sparse_categorical_crossentropy", "mse"],
              loss_weights=[0.8, 0.2], # depends on what you care most about
              optimizer=optimizer, metrics=["accuracy"])

# %% [markdown]
# IoU(intersection over union) : 바운딩 박스에 널리 사용되는 지표. 예측한 바운딩 박스와 타깃 바운딩 박스 사이에 중첩되는 영역을 전체 영역으로 나눈 것.
#
# # 14.9 객체 탐지
# 객체 탐지(object detection) : 하나의 이미지에서 여러 물체를 분류하고 위치를 추정하는 작업.
#
# ## 14.9.1 완전 합성곱 신경망(fully convolutional network, FCN)
# ## 14.9.2 YOLO(you only look once)
# 신경망을 훈련하기 전에 **앵커 박스**(anchor box, 사전 바운딩 박스 bounding box prior)라 부르는 대표 바운딩 박스 크기를 찾는다. <br/>
# 각 격자 셀과 각 앵커 박스마다 네트워크는 수직, 수평 방향 스케일 조정 비율의 로그값을 예측해 적절한 차원의 바운딩 박스를 예측한다.
#
# 계층적 분류를 사용하는 YOLO9000 모델은 **WordTree**라 부르는 시각 계층의 각 노드에 대한 확률을 예측한다.
#
# ### mAP
# - 평균 정밀도(average precision, AP) : 재현율에서의 최대 정밀도를 계산해 그 평균을 구한 것.
# - mAP(mean average precision) : 객체 탐지에서 널리 사용하는 평가 지표. 각 클래스에 대해 AP를 계산한 다음 평균 AP를 계산한 것.
#
# Faster R-CNN : 이미지가 CNN 하나를 통과해 그 출력을 **RPN**(Region proposal network)으로 전달해 객체가 들어있을 가능성이 높은 바운딩 박스를 출력. <br/>
# 이 CNN의 출력을 기반으로 바운딩 박스마다 분류기를 실행하는 것.
#
# # 14.10 시맨틱 분할(semantic segmentation)
# CNN의 전체 스트라이드는 32인데, 너무 듬성듬성하기 때문에 해상도를 32배로 늘리는 **업샘플링 층**(upsampling layer)을 추가한다. <br/>
# 업샘플링 방법으로 **전치 합성곱 층**(transposed convolutional layer)을 사용했다.
#
# ## 텐서플로 합성곱 연산
# - `keras.layers.Conv1D`
# - `keras.layers.Conv3D`
# - `dilation_rate` : 매개변수를 2 이상으로 지정하면 **아트루스 합성곱 층**(atrous convolution layer)이 된다.
